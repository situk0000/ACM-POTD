# %% [markdown]
# <a href="https://colab.research.google.com/github/situk0000/ACM-POTD/blob/main/Machine_Learning_for_Water_Quality_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "pH": [7.1, 6.8, 8.0, 7.5],
    "TDS": [300, 450, 500, 350],
    "Conductivity": [600, 800, 900, 700],
    "Quality": ["Good", "Moderate", "Poor", "Good"]
}

df = pd.DataFrame(data)
df
# Out:
#     pH  TDS  Conductivity   Quality
# 0  7.1  300           600      Good
# 1  6.8  450           800  Moderate
# 2  8.0  500           900      Poor
# 3  7.5  350           700      Good

# %% [markdown]
# # Research Mini Project
# This notebook shows sample water quality parameters such as pH, TDS, and conductivity.
